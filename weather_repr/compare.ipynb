# %%
from weather.weather_simulator import WeatherSimulator
from weather_repr.plot_weather import plot_weather
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from weather.weather_simulator import WeatherSimulator
#       2 from weather_repr.plot_weather import plot_weather
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'weather'
